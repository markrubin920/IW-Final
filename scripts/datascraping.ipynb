# %%
import pandas as pd
from pybaseball import statcast, pybaseball

# %% [markdown]
# Get Column Info

# %%
pybaseball.playerid_lookup("Judge", "Aaron")
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     judge      aaron     592450  judga001  judgeaa01          15640
#
#    mlb_played_first  mlb_played_last
# 0            2016.0           2025.0

# %% [markdown]
# Issue with this is it only shows the performance against a specific pitch type but not location

# %%
pybaseball.statcast_batter_pitch_arsenal(2023)
# Out:
#      last_name, first_name  player_id team_name_alt pitch_type  \
# 0            Bregman, Alex     608324           HOU         FF
# 1             Kwan, Steven     680757           CLE         FF
# 2           Crawford, J.P.     641487           SEA         FF
# 3          Lowe, Nathaniel     663993           TEX         FF
# 4           Semien, Marcus     543760           TEX         FF
# ...                    ...        ...           ...        ...
# 2352       Alberto, Hanser     593643           CWS         SL
# 2353        Realmuto, J.T.     592663           PHI         ST
# 2354        Blanco, Dairon     680118            KC         SL
# 2355          Ward, Taylor     621493           LAA         ST
# 2356     Yastrzemski, Mike     573262            SF         CU
#
#            pitch_name  run_value_per_100  run_value  pitches  pitch_usage  \
# 0     4-Seam Fastball                0.7          6      914         32.8
# ...

# %%
statcast(start_dt="2016-01-01", end_dt="2024-12-30").to_csv("../data/merged.csv")

# %%
df_all = pd.read_csv('../data/merged.csv')

# %%
df_all
# Out:
#         Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0              323         CU  2016-11-02           76.6           2.93
# 1              335         CU  2016-11-02           74.3           3.04
# 2              200         FF  2016-11-02           94.9          -1.29
# 3              205         FF  2016-11-02           95.6          -1.28
# 4              215         FF  2016-11-02           94.8          -1.13
# ...            ...        ...         ...            ...            ...
# 757709        1711        NaN  2024-03-15            NaN            NaN
# 757710        1762        NaN  2024-03-15            NaN            NaN
# 757711        1924        NaN  2024-03-15            NaN            NaN
# 757712        2007        NaN  2024-03-15            NaN            NaN
# 757713        2112        NaN  2024-03-15            NaN            NaN
#
#         release_pos_z        player_name  batter  pitcher     events  ...  \
# ...

# %%
df_all[df_all['batter'] == 608324]
# Out:
#         Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 26550         2287         FC  2016-09-28           85.3          -1.78
# 26551         2396         FF  2016-09-28           89.2          -1.84
# 26620          157         FF  2016-09-28           96.6           2.45
# 26621          186         KC  2016-09-28           80.3           2.56
# 26622          205         FF  2016-09-28           96.2           2.49
# ...            ...        ...         ...            ...            ...
# 748895        1836         SI  2024-03-17           95.5           0.70
# 756798        1490        NaN  2024-03-15            NaN            NaN
# 756824        2079        NaN  2024-03-15            NaN            NaN
# 756857         862        NaN  2024-03-15            NaN            NaN
# 756876        1664        NaN  2024-03-15            NaN            NaN
#
#         release_pos_z          player_name  batter  pitcher     events  ...  \
# ...
